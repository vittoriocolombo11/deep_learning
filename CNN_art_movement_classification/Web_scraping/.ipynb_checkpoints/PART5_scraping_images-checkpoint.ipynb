# %%
import pandas as pd
import os
import requests
import numpy as np
import time
from fake_useragent import UserAgent
from help_functions import is_file_saved

df = pd.read_csv("images_to_scrape.csv").iloc[:,1:]

#=====================
# CREATE THE FOLDERS 
#=====================
cwd = os.getcwd()
OUT_FOLDER = "raw_data"

if not os.path.exists(cwd + f'/{OUT_FOLDER}'):
    os.mkdir(cwd + f'/{OUT_FOLDER}')
os.chdir(cwd + f'/{OUT_FOLDER}')

main_dirs = ['train', 'validation', 'test']
categories = df.art_movement.unique().tolist()

for m in main_dirs:
    newdir = cwd + f"/{OUT_FOLDER}/{m}"
    if not os.path.exists(newdir):
        os.mkdir(newdir)
    for cat in categories:
        subdir = newdir + f"/{cat}"
        if not os.path.exists(subdir):
            os.mkdir(subdir)
os.chdir(cwd)


#=========================
# SCRAPING THE IMAGES
#=========================

# keeping only obs in train, val, test (sorry means "sorry, youre not part of the team")
my_df = df[~df.folder.str.contains("sorry")].reset_index().loc[:,['folder', 'art_movement', 'jpeg', 'image_name']] # keeping only train, val and test
# creating a column to update when image is scraped AND saved
my_df['scrape_state']=['not_scraped'] * len(my_df)

# initialize fake user agent
fake_agent = UserAgent().random
headers = {'User-Agent': fake_agent}
CHANGE_RATE = 100
SLEEP_TIME = 1.5

for i in range(len(my_df)):
    # two info to move in the right folder, in order to save the imaege
    folder = my_df.folder[i]
    cat = my_df.art_movement[i]
    
    newdir = f"{cwd}/{OUT_FOLDER}/{folder}/{cat}" # that's the directory where I will go
    jpeg_link = my_df.jpeg[i] # link to get through requests
    image_name = my_df.image_name[i]+'.jpg' # image name to save the image
    
    # changing the user agent every MAX_REQUESTS:
    if i%CHANGE_RATE == 0:
        fake_agent = UserAgent().random
        headers = {'User-Agent': fake_agent}
        print(f"{str(i)} images done, changing agent")
    else:
        pass
    
    # now we make the request and see the status
    if requests.get(jpeg_link).status_code != 200: # request not accepted
        my_df.loc[i, "scrape_state"]="invalid request"
        print("error request")
    else: # request was successful
        image=requests.get(jpeg_link).content # this is our image        
        os.chdir(newdir) # changing directory
        with open(f"{image_name}", 'wb') as handle:   
            handle.write(image)
        handle.close()
        if is_file_saved(newdir, image_name):
            my_df.loc[i, "scrape_state"]='saved'
        else:
            my_df.loc[i, "scrape_state"]='unable to save'
            print("error saving")
    
    time.sleep(SLEEP_TIME)
    
os.chdir(cwd)
print("unable to get", len(my_df[my_df['scrape_state']!="saved"]), "images.")
my_df.to_csv("scraping_results.csv")
# Out:
# 0 images done, changing agent
# 100 images done, changing agent
# 200 images done, changing agent
# 300 images done, changing agent
# 400 images done, changing agent
# 500 images done, changing agent
# 600 images done, changing agent
# 700 images done, changing agent
# 800 images done, changing agent
# 900 images done, changing agent
# 1000 images done, changing agent
# 1100 images done, changing agent
# 1200 images done, changing agent
# 1300 images done, changing agent
# 1400 images done, changing agent
# 1500 images done, changing agent
# 1600 images done, changing agent
# 1700 images done, changing agent
# 1800 images done, changing agent
# 1900 images done, changing agent
# 2000 images done, changing agent
# 2100 images done, changing agent
# 2200 images done, changing agent
# 2300 images done, changing agent
# 2400 images done, changing agent
# 2500 images done, changing agent
# 2600 images done, changing agent
# 2700 images done, changing agent
# 2800 images done, changing agent
# 2900 images done, changing agent
# 3000 images done, changing agent
# 3100 images done, changing agent
# 3200 images done, changing agent
# 3300 images done, changing agent
# 3400 images done, changing agent
# 3500 images done, changing agent
# 3600 images done, changing agent
# 3700 images done, changing agent
# 3800 images done, changing agent
# 3900 images done, changing agent
# 4000 images done, changing agent
# 4100 images done, changing agent
# 4200 images done, changing agent
# 4300 images done, changing agent
# 4400 images done, changing agent
# 4500 images done, changing agent
# 4600 images done, changing agent
# 4700 images done, changing agent
# 4800 images done, changing agent
# 4900 images done, changing agent
# 5000 images done, changing agent
# 5100 images done, changing agent
# 5200 images done, changing agent
# 5300 images done, changing agent
# 5400 images done, changing agent
# 5500 images done, changing agent
# 5600 images done, changing agent
# 5700 images done, changing agent
# 5800 images done, changing agent
# 5900 images done, changing agent
# 6000 images done, changing agent
# 6100 images done, changing agent
# 6200 images done, changing agent
# 6300 images done, changing agent
# 6400 images done, changing agent
# 6500 images done, changing agent
# 6600 images done, changing agent
# 6700 images done, changing agent
# 6800 images done, changing agent
# 6900 images done, changing agent
# 7000 images done, changing agent
# 7100 images done, changing agent
# 7200 images done, changing agent
# 7300 images done, changing agent
# 7400 images done, changing agent
# 7500 images done, changing agent
# 7600 images done, changing agent
# 7700 images done, changing agent
# 7800 images done, changing agent
# 7900 images done, changing agent
# 8000 images done, changing agent
# 8100 images done, changing agent
# 8200 images done, changing agent
# 8300 images done, changing agent
# 8400 images done, changing agent
# 8500 images done, changing agent
# 8600 images done, changing agent
# 8700 images done, changing agent
# 8800 images done, changing agent
# 8900 images done, changing agent
# 9000 images done, changing agent
# 9100 images done, changing agent
# 9200 images done, changing agent
# 9300 images done, changing agent
# 9400 images done, changing agent
# 9500 images done, changing agent
# 9600 images done, changing agent
# 9700 images done, changing agent
# 9800 images done, changing agent
# 9900 images done, changing agent
# 10000 images done, changing agent
# 10100 images done, changing agent
# 10200 images done, changing agent
# 10300 images done, changing agent
# 10400 images done, changing agent
# 10500 images done, changing agent
# 10600 images done, changing agent
# 10700 images done, changing agent
# 10800 images done, changing agent
# 10900 images done, changing agent
# 11000 images done, changing agent
# 11100 images done, changing agent
# 11200 images done, changing agent
# 11300 images done, changing agent
# 11400 images done, changing agent
# 11500 images done, changing agent
# 11600 images done, changing agent
# 11700 images done, changing agent
# 11800 images done, changing agent
# 11900 images done, changing agent
# 12000 images done, changing agent
# 12100 images done, changing agent
# 12200 images done, changing agent
# 12300 images done, changing agent
# 12400 images done, changing agent
# 12500 images done, changing agent
# 12600 images done, changing agent
# 12700 images done, changing agent
# 12800 images done, changing agent
# 12900 images done, changing agent
# 13000 images done, changing agent
# 13100 images done, changing agent
# 13200 images done, changing agent
# 13300 images done, changing agent
# 13400 images done, changing agent
# 13500 images done, changing agent
# 13600 images done, changing agent
# 13700 images done, changing agent
# 13800 images done, changing agent
# 13900 images done, changing agent
# 14000 images done, changing agent
# 14100 images done, changing agent
# 14200 images done, changing agent
# 14300 images done, changing agent
# 14400 images done, changing agent
# 14500 images done, changing agent
# 14600 images done, changing agent
# 14700 images done, changing agent
# 14800 images done, changing agent
# 14900 images done, changing agent
# 15000 images done, changing agent
# 15100 images done, changing agent
# 15200 images done, changing agent
# 15300 images done, changing agent
# 15400 images done, changing agent
# 15500 images done, changing agent
# 15600 images done, changing agent
# 15700 images done, changing agent
# 15800 images done, changing agent
# 15900 images done, changing agent
# unable to get 0 images.
